# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="",
    temperature=0,
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
    # other params...
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_groq import ChatGroq
#       3 llm = ChatGroq(
#       4     model="qwen/qwen3-32b",
#       5     temperature=0,
#    (...)
#      10     # other params...
#      11 )
#
# ModuleNotFoundError: No module named 'langchain_groq'

# %%
pip install langchain_groq
# Out:
# Collecting langchain_groqNote: you may need to restart the kernel to use updated packages.
#
#   Using cached langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-core<2.0.0,>=1.2.8 (from langchain_groq)
#   Using cached langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\jetta\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jetta\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.2.8->langchain_groq)
#   Using cached langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.8->langchain_groq)
#   Using cached langsmith-0.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\jetta\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jetta\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jetta\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (8.2.3)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.8->langchain_groq)
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\jetta\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.7)
# Requirement already satisfied: certifi in c:\users\jetta\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\jetta\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jetta\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jetta\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq)
#   Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jetta\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jetta\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.3)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq)
#   Downloading xxhash-3.7.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jetta\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jetta\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jetta\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jetta\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jetta\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.2.3)
# Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Using cached langchain_core-1.3.2-py3-none-any.whl (542 kB)
# Using cached langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Using cached langsmith-0.8.0-py3-none-any.whl (393 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl (127 kB)
# Downloading xxhash-3.7.0-cp312-cp312-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, uuid-utils, orjson, langchain-protocol, langsmith, groq, langchain-core, langchain_groq
# Successfully installed groq-0.37.1 langchain-core-1.3.2 langchain-protocol-0.0.15 langchain_groq-1.1.2 langsmith-0.8.0 orjson-3.11.8 uuid-utils-0.14.1 xxhash-3.7.0

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    model_name="llama-3.1-8b-instant",
    groq_api_key='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', 
)

response = llm.invoke("The first person to land on moon was ?")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
pip install chromadb
# Out:
# Collecting chromadbNote: you may need to restart the kernel to use updated packages.
#
#   Downloading chromadb-1.5.8-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic>=2.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (2.6.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.25.1-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (1.39.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (1.76.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\jetta\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\jetta\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\jetta\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\jetta\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\jetta\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\jetta\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\jetta\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\jetta\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jetta\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jetta\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jetta\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jetta\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jetta\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\jetta\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\jetta\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\jetta\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\jetta\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\jetta\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf in c:\users\jetta\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\jetta\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\jetta\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.62b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jetta\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jetta\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\jetta\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jetta\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jetta\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-1.13.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jetta\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp312-cp312-win_amd64.whl.metadata (3.6 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\jetta\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jetta\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\jetta\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jetta\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jetta\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading chromadb-1.5.8-cp39-abi3-win_amd64.whl (23.4 MB)
#    ---------------------------------------- 0.0/23.4 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/23.4 MB 7.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.9/23.4 MB 7.0 MB/s eta 0:00:03
#    ------- -------------------------------- 4.2/23.4 MB 7.0 MB/s eta 0:00:03
#    --------- ------------------------------ 5.8/23.4 MB 6.9 MB/s eta 0:00:03
#    ------------ --------------------------- 7.3/23.4 MB 7.0 MB/s eta 0:00:03
#    --------------- ------------------------ 8.9/23.4 MB 7.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.2/23.4 MB 7.0 MB/s eta 0:00:02
#    -------------------- ------------------- 11.8/23.4 MB 7.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.4/23.4 MB 7.0 MB/s eta 0:00:02
#    ------------------------- -------------- 14.7/23.4 MB 7.0 MB/s eta 0:00:02
#    --------------------------- ------------ 16.3/23.4 MB 7.0 MB/s eta 0:00:02
#    ------------------------------ --------- 17.6/23.4 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 19.1/23.4 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.7/23.4 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 21.8/23.4 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 22.0/23.4 MB 6.6 MB/s eta 0:00:01
#    -------------------------------------- - 22.5/23.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  23.3/23.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 23.4/23.4 MB 5.9 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 16.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 671.0 kB/s eta 0:00:02
#    -------------------- ------------------- 1.0/2.0 MB 671.0 kB/s eta 0:00:02
#    -------------------- ------------------- 1.0/2.0 MB 671.0 kB/s eta 0:00:02
#    ------------------------- -------------- 1.3/2.0 MB 541.1 kB/s eta 0:00:02
#    ------------------------------- -------- 1.6/2.0 MB 671.1 kB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 671.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 641.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 634.7 kB/s eta 0:00:00
# Downloading mmh3-5.2.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.25.1-cp312-cp312-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.9 MB 322.4 kB/s eta 0:00:39
#    - -------------------------------------- 0.5/12.9 MB 322.4 kB/s eta 0:00:39
#    - -------------------------------------- 0.5/12.9 MB 322.4 kB/s eta 0:00:39
#    - -------------------------------------- 0.5/12.9 MB 322.4 kB/s eta 0:00:39
#    -- ------------------------------------- 0.8/12.9 MB 332.2 kB/s eta 0:00:37
#    ---- ----------------------------------- 1.3/12.9 MB 545.6 kB/s eta 0:00:22
#    ----- ---------------------------------- 1.8/12.9 MB 745.8 kB/s eta 0:00:15
#    ------- -------------------------------- 2.4/12.9 MB 906.7 kB/s eta 0:00:12
#    -------- ------------------------------- 2.9/12.9 MB 1.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 3.4/12.9 MB 1.2 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.9 MB 1.2 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.9 MB 1.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.2/12.9 MB 1.5 MB/s eta 0:00:06
#    ------------------ --------------------- 6.0/12.9 MB 1.6 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/12.9 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/12.9 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/12.9 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/12.9 MB 1.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/12.9 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.1/12.9 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 8.7/12.9 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.2/12.9 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.9 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 10.2/12.9 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.9 MB 1.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/12.9 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 1.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
# Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
# Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
# Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl (35 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.8 MB 3.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 2.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 2.4/2.8 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 1.6 MB/s eta 0:00:00
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.7.1-cp312-cp312-win_amd64.whl (86 kB)
# Using cached huggingface_hub-1.13.0-py3-none-any.whl (660 kB)
# Downloading watchfiles-1.1.1-cp312-cp312-win_amd64.whl (288 kB)
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, websockets, pyproject_hooks, pybase64, opentelemetry-proto, onnxruntime, oauthlib, mmh3, importlib-resources, httptools, hf-xet, bcrypt, watchfiles, uvicorn, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, build, opentelemetry-semantic-conventions, kubernetes, huggingface-hub, tokenizers, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.39.1
#     Uninstalling opentelemetry-api-1.39.1:
#       Successfully uninstalled opentelemetry-api-1.39.1
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.8 durationpy-0.10 flatbuffers-25.12.19 hf-xet-1.4.3 httptools-0.7.1 huggingface-hub-1.13.0 importlib-resources-7.1.0 kubernetes-35.0.0 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.25.1 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 tokenizers-0.23.1 uvicorn-0.46.0 watchfiles-1.1.1 websockets-16.0
